# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

dataset_path = "/content/drive/MyDrive/caltech-small"

categories = os.listdir(dataset_path)

print(categories)
# Out:
# ['Faces', 'Faces_easy', 'Motorbikes', 'BACKGROUND_Google', 'Leopards']

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image
import numpy as np

# Load pretrained ResNet50 model
model = ResNet50(
    weights='imagenet',
    include_top=False,
    pooling='avg'
)

print("Model Loaded Successfully")
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model Loaded Successfully

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

model = ResNet50(weights="imagenet", include_top=False, pooling="avg")
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def extract_features(img_path):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))

    # Convert image to array
    img_array = image.img_to_array(img)

    # Expand dimensions
    img_array = np.expand_dims(img_array, axis=0)

    # Preprocess for ResNet50
    img_array = preprocess_input(img_array)

    # Extract features
    features = model.predict(img_array)

    # Flatten vector
    return features.flatten()

# %%
features_list = []
image_paths = []

for category in categories:

    folder_path = os.path.join(dataset_path, category)

    for img_name in os.listdir(folder_path)[:50]:

        img_path = os.path.join(folder_path, img_name)

        try:
            features = extract_features(img_path)

            features_list.append(features)
            image_paths.append(img_path)

            print(f"Processed: {img_name}")

        except:
            print(f"Error with: {img_name}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Processed: image_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Processed: image_0012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processed: image_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Processed: image_0016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Processed: image_0013.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Processed: image_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Processed: image_0014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Processed: image_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Processed: image_0011.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Processed: image_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Processed: image_0010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Processed: image_0079.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Processed: image_0073.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Processed: image_0020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

def find_similar_images(query_path, top_n=5):

    # Extract query image features
    query_features = extract_features(query_path)

    # Calculate similarity
    similarities = cosine_similarity(
        [query_features],
        features_list
    )[0]

    # Get top matches
    top_indices = similarities.argsort()[-top_n:][::-1]

    return [image_paths[i] for i in top_indices]

# %%
query_image = "/content/drive/MyDrive/caltech-small/Motorbikes/image_0001.jpg"

# %%
import os

motorbike_path = "/content/drive/MyDrive/caltech-small/Motorbikes"

print(os.listdir(motorbike_path)[:5])
# Out:
# ['image_0012.jpg', 'image_0022.jpg', 'image_0005.jpg', 'image_0007.jpg', 'image_0013.jpg']

# %%
import os

motorbike_path = "/content/drive/MyDrive/caltech-small/Motorbikes"

print(os.listdir(motorbike_path)[:5])
# Out:
# ['image_0012.jpg', 'image_0022.jpg', 'image_0005.jpg', 'image_0007.jpg', 'image_0013.jpg']

# %%
from tensorflow.keras.preprocessing import image

# %%
import numpy as np

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.models import Model

# %%
query_image = "/content/drive/MyDrive/caltech-small/Motorbikes/image_0012.jpg"

results = find_similar_images(query_image)

print(results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# ['/content/drive/MyDrive/caltech-small/Motorbikes/image_0012.jpg', '/content/drive/MyDrive/caltech-small/Motorbikes/image_0013.jpg', '/content/drive/MyDrive/caltech-small/Motorbikes/image_0005.jpg', '/content/drive/MyDrive/caltech-small/Motorbikes/image_0018.jpg', '/content/drive/MyDrive/caltech-small/Motorbikes/image_0016.jpg']

# %%
import matplotlib.pyplot as plt
import cv2

for img_path in results:
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(img)
    plt.title(img_path.split("/")[-1])
    plt.axis("off")
    plt.show()
